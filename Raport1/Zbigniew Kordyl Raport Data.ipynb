# %% [markdown]
# # Wstęp teoretyczny

# %% [markdown]
# Na wykładzie wstępnie przedstawiono historie nauki o danych gdzie podane były konkretne przykłady.
# Najbardziej z tych przykładów zapamiętałem  "Mechanizm z Antykithiry" ,którego zdjęcie zamieściłem poniżej.
#
# ![obrazek1.jpg](attachment:obrazek1.jpg)
#
# Później omawiane były podstawy programowania gdzie omawialiśmy miedzy innymi:
#
# * jak zainstalować pythona
# * jakie mamy typy skalarne czyli:
#     * całkowite
#     * zmiennopozycyjne
#     * zespolone
# * operacje które możemy na nich wykonać
# * jakie są typy sekwencyjne i interowalne
#     * zmienialne (listy)
#     * niezmienialne (krotki, napisy)
# * również ich możliwości i ograniczenia
#
#
# Najważniejsze komendy jakie poznaliśmy na wykładzie to:
# * jak wydrukować wartość czyli:
#     > print("Hello world")
#
# * operacje matematyczne:
#     > dodawanie = 1 + 1
#     > odejmowanie = 1 - 1
#     > mnożenie = 1 * 1
#     > dzielenie = 1/2
#     > potegowanie = 2**3
#
# * deklarowanie listy,krotki, zakresu i napisu:
#     > list = [ ]
#     > krotka = ( )
#     > zakres = range(7)
#     > napisy = "Dobrze"

# %% [markdown]
# # Rozwiązania

# %% [markdown]
# Pierwsze dwa zadania polegały na zainstalowaniu środowiska Anacondy i notatnika jupyter.
# Trzecie polegało na przetestowanoiu możliwości biblioteki markdown, gdzie dowiedziałem sie jak łatwo można edytowac tekst w notkatniku jupyter. Zacheciło mnie to też do wiekszego zgłębienia tematu.
# Kolejne zadania przedstawie w formie rozwiązań i krotkiego komentarza.

# %% [markdown]
# # Zadanie 4

# %% [markdown]
# W tym zadaniu należało uzyć komendy `print()` aby wyświetlić podane niżej działania. Równie dobrze można było nie pisac tej kmendy a wyniki obliczeń by sie wyświetliły.

# %%
print (100 + 100)  
450 / 2
# Out:
# 200
# 225.0

# %% [markdown]
# # Zadanie 5

# %% [markdown]
# Tu policzyłem ogólną średnia długość życia w Norwegi czyli średnia długość życia mężczyzny to 80.6 lat a kobiety to 84.3 co w rezultacie daje średnią 82.5

# %%
10**9 <= (((80.6+84.4)/2) * 31556926)
# Out:
# True

# %% [markdown]
# Wiec noworodek urodzony w Norwegii ma szansę przeżyć $10^9$ sekund.

# %% [markdown]
# # Zadanie 6

# %% [markdown]
# Tu należało przerobić wzór żeby policzyć mase.

# %%
print (0.0012 * 1000) #powietrze 
print (0.67 * 1000) #benzyna
print (0.9 * 1000) #lód
print (1.0 * 1000) #czysta woda
print (1.025 * 1000) #woda morska
print (1.03 * 1000) #ciało człowieka
# Out:
# 1.2
# 670.0
# 900.0
# 1000.0
# 1025.0
# 1030.0

# %% [markdown]
# # Zadanie 7

# %%
C = A + B  
A = 3  
B = 2  
print(C)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-2762f53e71a8> in <module>
# ----> 1 C = A + B
#       2 A = 3
#       3 B = 2
#       4 print(C)
#
# NameError: name 'A' is not defined

# %%
Program nie działa ponieważ zmienna A i  B nie jest zdefiniowana przed wykonaniem na nich operacji.

# %% [markdown]
# # Zadanie 8

# %% [markdown]
# ## Fragment 1

# %%
v0 = 3 #[m/s] 
t = 1 #[s]
a = 2 #[m/s**2]
s = v0*t + 1/2 * a*t**2
print(s)
# Out:
# 4.0

# %% [markdown]
# Wykasztagowałem jednostki przez które program nie działał

# %% [markdown]
# # Fragment 2

# %%
a = 3.3 #tu krotka na zmiennoprzecinkowa
b = 5.3
a2 = a**2
b2 = b**2

e1_sum = a2 + 2*a*b + b2 # dodane mnożenie
e2_sum = a2 - 2*a*b + b2

e1_pow  = (a + b)**2
e2_pow  = (a - b)**2

print("Pierwsze rownanie %g = %g" % (e1_sum, e1_pow))
print("Drugie rownanie %g = %g" % (e2_sum, e2_pow))
# Out:
# Pierwsze rownanie 73.96 = 73.96
# Drugie rownanie 4 = 4

# %% [markdown]
# W tym zadaniu zamieniłem deklaracje krotki na zmienna zmiennoprzecinkową i  należało dodać mnożenie w lini kodu `e1_sum = a2 + 2*a*b + b2`

# %% [markdown]
# # Zadanie 9

# %%
import math as mat
M_m = 47 #[g]
M_d = 67 #[g]
q = 1.038 #[g/cm3]
c = 3.7 #[J/gK]
K = 5.4 * 10**(-3) #[W/cmK]
T_w = 100 #[C]
T_o1 = 20
T_o2 = 4
T_y = 70

# %%
M = int(input("Wprowadź mase jajka\n"))
T_o = int(input("wprowadź temperature poczatkową\n"))
t = (M**(2/3)*c*q**(1/3))/(K*3.14**2*((4*3.14)/3)**(2/3)) * mat.log(0.76 * (T_o - T_w)/(T_y - T_w))/60
print ("Najefektywniejszy czas na ugotowanie jajka na miekko przy wadze {M} i temperaturze poczatkowej {T_o} stopni celcjusza  wynosi  {t} minut ".format(M=M, T_o=T_o, t=t))
# Out:
# Wprowadź mase jajka
# 47
# wprowadź temperature poczatkową
# 20
# Najefektywniejszy czas na ugotowanie jajka na miekko przy wadze 47 i temperaturze poczatkowej 20 stopni celcjusza  wynosi  4.153321404712377 minut

# %% [markdown]
# W tym zadaniu policzyłem najefektywnijszy czas jaki potrzeba na ugotowanie jajka na miękko. Usprawniłem kod żeby można było wpisywać różne wagi jajka i temperatury początkowej.

# %% [markdown]
# # Zadanie 10

# %%
lista_zakupów = ["herbata","kawa","ciastka","jajka","makaron","mleko","woda","szynka","ser","parówki de lux"]
lista_zakupów_2 = ("herbata","kawa","ciastka","jajka","makaron","mleko","woda","szynka","ser","parówki de lux")

lista_zakupów [4] = "piwo"
lista_zakupów_2 [4] = "piwo"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-9b45eeca50ff> in <module>
#       3
#       4 lista_zakupów [4] = "piwo"
# ----> 5 lista_zakupów_2 [4] = "piwo"
#       6
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# Stworzyliśmy liste i krotke z lista zakupów. W liście można zmienić zawartość  komórek a w krotce nie.

# %%
f = list(range(20,65,5))
C = [((x-30)/2) for x in f]
print(C)

# %% [markdown]
# Tu naszym zadaniem było przekonwertować stopnie Fahrenheita (w zakresie od 20-60 F) do skali Celsjusza wykorzystujac wyrażenia listotwórcze.

# %% [markdown]
# Wykorzystując wyrażenia listotwórcze należało wygenerować zbiór współrzędnych x w zakresie x∈[2,3] w odstępach równych Δ=0.01.

# %%
import numpy as np
x = list(np.arange(2,3,0.01))
print(x)
# Out:
# [2.0, 2.01, 2.0199999999999996, 2.0299999999999994, 2.039999999999999, 2.049999999999999, 2.0599999999999987, 2.0699999999999985, 2.0799999999999983, 2.089999999999998, 2.099999999999998, 2.1099999999999977, 2.1199999999999974, 2.1299999999999972, 2.139999999999997, 2.149999999999997, 2.1599999999999966, 2.1699999999999964, 2.179999999999996, 2.189999999999996, 2.1999999999999957, 2.2099999999999955, 2.2199999999999953, 2.229999999999995, 2.239999999999995, 2.2499999999999947, 2.2599999999999945, 2.2699999999999942, 2.279999999999994, 2.289999999999994, 2.2999999999999936, 2.3099999999999934, 2.319999999999993, 2.329999999999993, 2.3399999999999928, 2.3499999999999925, 2.3599999999999923, 2.369999999999992, 2.379999999999992, 2.3899999999999917, 2.3999999999999915, 2.4099999999999913, 2.419999999999991, 2.429999999999991, 2.4399999999999906, 2.4499999999999904, 2.45999999999999, 2.46999999999999, 2.4799999999999898, 2.4899999999999896, 2.4999999999999893, 2.509999999999989, 2.5199999
# ...

# %% [markdown]
# Wykorzystałem do tego biblioteke numpy żeby tworzyć zakresy w zmiennych zmiennoprzecinkowych,  chiciaż wynik mnie nie zadowala.

# %% [markdown]
# # Wnioski

# %% [markdown]
# Jeśli chodzi o wiedze jaką uzyskałem podczas tych zajeć mogłbym uznać że kilka rzeczy się utrwaliło.
# Nowością była biblioteka Markdown z której nie korzystałem gdy zaczynałem przygodę z Pythonem.
# Wiedza uzyskana przełoży się w lepszej estetyce raportów.
